# %% [markdown]
# # EICU data from the Dungog East Coast Low

# %% [markdown]
# This notebook imports and explores the cleaned up data from the EICU for the Dungug East Coast Low event. The data have been cleaned to remove empty fields, and an error in the lat/lon values for Medowie (where the lat and lon values were swapped).
#
# The working directory for this project is:
#
# *\\nas\gemd\georisk\HaRIA_B_Wind\projects\impact_forecasting\data\exposure\NSW\April_2015_Impact_Assessment*
#
# **Date: August 2017, Creator: Claire Krause**

# %% [markdown]
# The data have been combined with outputs from the BoM's high resolution Dungog East Coast Low model ensemble. The netcdf outputs from the model were converted to Geotiffs using gdal_translate
#
# `e.g. gdal_translate -of GTiff NETCDF:combined_alltimes_accum_ls_rainrate_stage4_ens00.nc:lsrain combined_alltimes_accum_ls_rainrate_stage4_ens00.tif`
#
# The Geotiffs were then read into ArcGIS, along side the EICU data. The model raster value at each EICU location was determined using the following code:
#
# `import arcpy
# from arcpy.sa import *
# arcpy.CheckOutExtension('Spatial')
# ExtractValuesToPoints("<observation_points>", "<TCRMwindfield>.tif", "<outputlayername>", "NONE", "VALUE_ONLY")`
#
# The raster values were exported to a .txt file, and added to the final columns of the EICU data.

# %% [markdown]
# # Set up the notebook

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from os.path import join as pjoin
import pandas as pd
import geopandas as gpd
import numpy as np

import seaborn as sns
sns.set_context("talk")
sns.set_style("whitegrid")
sns.set_palette("hls")

# %% [markdown]
# # Start by reading in an exploring the dataset

# %%
data_path = "X:/georisk/HaRIA_B_Wind/projects/impact_forecasting/data/impact/dungog"
filename = "damage_hazard.shp"
filepath = pjoin(data_path, filename)

df = gpd.read_file(filepath)
df
# Out:
#       OBJECTID_1  OBJECTID_2  OBJECTID  createdate               srcid  \
# 0            136           1         1  2015-05-02  FRNSW2015521449.14
# 1            137           2         2  2015-05-02   FRRA2015521549.54
# 2            138           3         3  2015-05-02   FRRA2015521631.18
# 3            139           4         4  2015-05-03    FRNSW201553122.3
# 4            140           5         5  2015-05-03  FRNSW2015531214.12
# 5            141           6         6  2015-05-03    FRRA2015531159.8
# 6            142           7         7  2015-05-03   FRRA2015531211.14
# 7            143           8         8  2015-05-03   FRRA2015531212.22
# 8            144           9         9  2015-05-03  FRNSW2015531243.57
# 9            145          10        10  2015-05-03  FRNSW2015531433.34
# 10           146          11        11  2015-05-03   FRNSW2015531446.8
# 11           147          12        12  2015-05-03  FRNSW2015531424.10
# 12           148          13        13  2015-05-03  FRNSW2015531437.33
# 13           149          14        14  2015-05-03   FRNSW201553158.34
# 14           150          15        15  2015-05-03    FRNSW201553158.0
# 15           151          16        16  2015-05-03   FRRA2015531539.24
# 16           152          17        17  2015-05-05  FRNSW2015551224.14
# 17           153          18        18  2015-05-05  FRNSW2015551454.20
# 18           154          19        19  2015-05-05   FRNSW201555159.42
# 19           155          20        20  2015-05-05  FRNSW2015551519.16
# 20           156          21        21  2015-05-05  FRNSW2015551510.47
# 21           157          22        22  2015-05-02  FRNSW2015521239.23
# 22           158          23        23  2015-05-02   FRNSW2015521520.9
# 23           159          24        24  2015-05-02  FRNSW2015521447.34
# 24           160          25        25  2015-05-02    FRRA201552160.15
# 25           161          26        26  2015-05-02    FRRA201552168.50
# 26           162          27        27  2015-05-03   FRNSW2015531013.6
# 27           163          28        28  2015-05-03  FRNSW2015531015.36
# 28           164          29        29  2015-05-03   FRNSW201553114.30
# 29           165          30        30  2015-05-03    FRRA201553112.30
# ...          ...         ...       ...         ...                 ...
# 2042        2178        2043      2043  2015-05-05                None
# 2043        2179        2044      2044  2015-05-05                None
# 2044        2180        2045      2045  2015-05-05                None
# 2045        2181        2046      2046  2015-05-05                None
# 2046        2182        2047      2047  2015-05-05                None
# 2047        2183        2048      2048  2015-05-05                None
# 2048        2184        2049      2049  2015-05-05                None
# 2049        2185        2050      2050  2015-05-05                None
# 2050        2186        2051      2051  2015-05-05                None
# 2051        2187        2052      2052  2015-05-06                None
# 2052        2188        2053      2053  2015-05-06                None
# 2053        2189        2054      2054  2015-05-06                None
# 2054        2190        2055      2055  2015-05-06                None
# 2055        2191        2056      2056  2015-05-06                None
# 2056        2192        2057      2057  2015-05-06                None
# 2057        2193        2058      2058  2015-05-06                None
# 2058        2194        2059      2059  2015-05-06                None
# 2059        2195        2060      2060  2015-05-06                None
# 2060        2196        2061      2061  2015-05-06                None
# 2061        2197        2062      2062  2015-05-06                None
# 2062        2198        2063      2063  2015-05-06                None
# 2063        2199        2064      2064  2015-05-06                None
# 2064        2200        2065      2065  2015-05-06                None
# 2065        2201        2066      2066  2015-05-06                None
# 2066        2202        2067      2067  2015-05-06                None
# 2067        2203        2068      2068  2015-05-06                None
# 2068        2204        2069      2069  2015-05-06                None
# 2069        2205        2070      2070  2015-05-06                None
# 2070        2206        2071      2071  2015-05-06                None
# 2071        2207        2072      2072  2015-05-06                None
#
#                assessoff title      teamid    dateinsp         agency  ...  \
# 0        David Wrightson  None      NSWTF1  2015-05-02          FRNSW  ...
# 1             Ray Irving  None      NSWTF1  2015-05-02          FRNSW  ...
# 2             Ray Irving  None      NSWTF1  2015-05-02          FRNSW  ...
# 3            Paul Hughes  None      NSWTF1  2015-05-03          FRNSW  ...
# 4          Keith Sanchez  None      NSWTF1  2015-05-03          FRNSW  ...
# 5             Ray Irving  None      NSWTF1  2015-05-03          FRNSW  ...
# 6             Ray Irving  None      NSWTF1  2015-05-03          FRNSW  ...
# 7             Ray Irving  None      NSWTF1  2015-05-03          FRNSW  ...
# 8          Deryck Salfus  None      NSWTF1  2015-05-03          FRNSW  ...
# 9          Duncan Armour  None      NSWTF1  2015-05-03          FRNSW  ...
# 10         Shaun Clapham  None      NSWTF1  2015-05-03          FRNSW  ...
# 11       Wayne Fergusson  None      NSWTF1  2015-05-03          FRNSW  ...
# 12       Wayne Fergusson  None      NSWTF1  2015-05-03          FRNSW  ...
# 13        Jose Caraballo  None      NSWTF1  2015-05-03          FRNSW  ...
# 14       Wayne Fergusson  None      NSWTF1  2015-05-03          FRNSW  ...
# 15            Ray Irving  None      NSWTF1  2015-05-03          FRNSW  ...
# 16    Christopher Hughes  None      NSWTF1  2015-05-05          FRNSW  ...
# 17          David Turner  None      NSWTF1  2015-05-05          FRNSW  ...
# 18          David Turner  None      NSWTF1  2015-05-05          FRNSW  ...
# 19     Christopher Lyons  None      NSWTF1  2015-05-05          FRNSW  ...
# 20          Jock Gilmour  None      NSWTF1  2015-05-05          FRNSW  ...
# 21         Deryck Salfus  None      NSWTF1  2015-05-02          FRNSW  ...
# 22        John Petterson  None      NSWTF1  2015-05-02          FRNSW  ...
# 23     Anthony Camilleri  None      NSWTF1  2015-05-02          FRNSW  ...
# 24            Ray Irving  None      NSWTF1  2015-05-02          FRNSW  ...
# 25            Ray Irving  None      NSWTF1  2015-05-02          FRNSW  ...
# 26         Shaun Clapham  None      NSWTF1  2015-05-03          FRNSW  ...
# 27         Keith Sanchez  None      NSWTF1  2015-05-03          FRNSW  ...
# 28         Shaun Clapham  None      NSWTF1  2015-05-03          FRNSW  ...
# 29            Ray Irving  None      NSWTF1  2015-05-03          FRNSW  ...
# ...                  ...   ...         ...         ...            ...  ...
# 2042         Andrew Kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2043        Sarah Kemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2044         Andrew kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2045             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2046         Andrew kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2047             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2048        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2049         SarahKemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2050             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2051        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2052        Sarah Kemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2053         SarahKemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2054             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2055         SarahKemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2056             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2057                None  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2058         SarahKemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2059        Sarah Kemble  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2060         Andrew kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2061             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2062                None  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2063         Andrew kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2064        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2065             jasonh2  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2066        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2067        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2068         Andrew kaye  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2069        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2070        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
# 2071        Aaron Howard  None  TEAM_DELTA        None  NSWSES.agency  ...
#
#           N1RR     P1RR     P6RR      PIRR     PTEA    NSWG     PGWS     PSMW  \
# 0      63.4961  13.9727  52.2852   3.73828  168.266  43.625  35.0805  15.9650
# 1      63.4961  13.7266  52.9102   5.82422  183.738  43.375  34.2719  24.9242
# 2      63.4961  13.7266  52.9102   5.82422  183.738  43.375  33.5002  21.1794
# 3      63.4961  16.8711  52.8242   7.26563  192.453  43.250  33.5002  21.1794
# 4      63.4961  35.2617  61.4023  15.33200  285.902  42.500  33.9671  10.1592
# 5      63.4961  17.9297  51.9336   7.43359  224.227  42.500  34.2201  16.6764
# 6      63.4961  18.1914  54.4180   7.50781  231.535  42.500  34.2201  16.6764
# 7      63.4961  17.9297  51.9336   7.43359  224.227  42.500  34.3165  16.6764
# 8      62.9063  17.8711  56.8594   4.86719  179.465  43.625  35.6872  13.8489
# 9      63.4961  41.2422  53.0313  13.15230  214.664  42.750  34.7639  20.7847
# 10     62.9063  21.3828  54.3594   6.07813  185.363  44.625  36.4668  14.7582
# 11     63.4961  22.8398  53.1094   9.64063  198.453  42.750  33.8436  16.1636
# 12     63.4961  22.8398  53.1094   9.64063  198.453  42.750  33.8436  16.1636
# 13     63.4961  13.0586  52.8008   3.92969  170.934  43.625  35.0805  15.9650
# 14     63.4961  22.8398  53.1094   9.64063  198.453  42.750  33.8436  16.1636
# 15     63.4961  17.9297  51.9336   7.43359  224.227  42.500  34.2201  16.6764
# 16    115.0860  30.5508  81.0938  13.98830  238.922  41.000  38.4663  13.2901
# 17    121.1990  22.7305  71.3438   7.54297  228.781  42.250  38.6236  13.4913
# 18    121.1990  22.7305  71.3438   7.54297  228.781  42.250  38.6236  13.4913
# 19    121.1990  27.8750  81.0078  11.71880  223.121  41.375  37.3399  13.8559
# 20    108.9880  17.2930  60.5195   6.82031  207.547  39.000  36.4908  13.2931
# 21     63.4961  33.6133  58.9922  11.48830  232.496  42.500  36.2250  14.4000
# 22     63.4961  26.2852  52.3320  13.84770  222.238  42.500  33.4834  21.4691
# 23     63.4961  13.9180  53.9609   4.17578  179.152  43.375  33.5932  17.1192
# 24     63.4961  13.7266  52.9102   5.82422  183.738  43.375  34.2719  24.9242
# 25     63.4961  13.7266  52.9102   5.82422  183.738  43.375  34.2719  24.9242
# 26     62.9063  20.3828  53.7109   6.05078  180.145  44.625  36.3305  15.3456
# 27     63.4961  36.5703  62.0391  11.68750  290.879  42.500  33.7178  10.3074
# 28     62.9063  20.3828  53.7109   6.05078  180.145  44.625  36.4531  15.3456
# 29     63.4961  17.9297  51.9336   7.43359  224.227  42.500  34.3165  16.6764
# ...        ...      ...      ...       ...      ...     ...      ...      ...
# 2042  121.1990  32.0508  82.2148  18.75780  288.992  45.625  39.3821  13.7941
# 2043  121.1990  39.9414  93.8242  16.18750  315.332  46.250  39.3821  13.7941
# 2044  121.1990  32.0508  82.2148  18.75780  288.992  45.625  39.3821  13.7941
# 2045  121.1990  32.0508  82.2148  18.75780  288.992  45.625  39.3821  13.7941
# 2046  121.1990  32.0508  82.2148  18.75780  288.992  45.625  39.3821  13.7941
# 2047  121.1990  32.0508  82.2148  18.75780  288.992  45.625  39.3821  13.7941
# 2048  121.1990  42.0586  84.7148  16.81250  316.047  47.250  39.8768  13.9465
# 2049  121.1990  39.9414  93.8242  16.18750  315.332  46.250  39.8768  13.9465
# 2050  121.1990  31.3516  91.8711  11.54300  331.051  46.125  37.6269  13.0665
# 2051  121.1990  31.9961  82.9023  11.37110  319.395  47.250  39.8768  13.5383
# 2052  121.1990  31.9961  82.9023  11.37110  319.395  47.250  39.8768  13.5383
# 2053  121.1990  42.0586  84.7148  16.81250  316.047  47.250  39.8768  13.9465
# 2054  121.1990  31.3516  91.8711  11.54300  331.051  46.125  39.0002  13.1921
# 2055  121.1990  31.9961  82.9023  11.37110  319.395  47.250  40.2502  13.6131
# 2056  121.1990  31.3516  91.8711  11.54300  331.051  46.125  39.0002  13.1921
# 2057  121.1990  31.3516  91.8711  11.54300  331.051  46.125  39.0002  13.1921
# 2058  121.1990  31.3516  91.8711  11.54300  331.051  46.125  37.8752  13.1921
# 2059  121.1990  31.3516  91.8711  11.54300  331.051  46.125  37.8752  13.1921
# 2060  121.1990  31.3516  91.8711  11.54300  331.051  46.125  39.0002  13.1921
# 2061  121.1990  31.3516  91.8711  11.54300  331.051  46.125  39.0002  13.1921
# 2062  121.1990  35.3828  90.8555  10.89060  329.238  46.625  37.8752  13.1921
# 2063  121.1990  36.4102  95.6523  11.18360  340.973  47.250  38.2508  13.1924
# 2064  121.1990  35.3828  90.8555  10.89060  329.238  46.625  37.8752  13.1921
# 2065  121.1990  36.4102  95.6523  11.18360  340.973  47.250  39.3752  13.1924
# 2066  121.1990  35.3828  90.8555  10.89060  329.238  46.625  37.8752  13.1921
# 2067  121.1990  35.3828  90.8555  10.89060  329.238  46.625  37.8752  13.1921
# 2068  121.1990  36.4102  95.6523  11.18360  340.973  47.250  39.6268  13.5511
# 2069  121.1990  36.4102  95.6523  11.18360  340.973  47.250  38.2508  13.1924
# 2070  121.1990  36.0000  93.7891  10.08200  339.109  46.250  37.8752  12.8947
# 2071  121.1990  31.3516  91.8711  11.54300  331.051  46.125  37.8752  13.1921
#
#         PSWG                                      geometry
# 0     35.250   POINT (151.550240800073 -33.23331333034588)
# 1     36.125  POINT (151.5172484000936 -33.25966973007394)
# 2     36.125   POINT (151.5087466600304 -33.2562306398321)
# 3     37.625  POINT (151.5038386000714 -33.25280849011966)
# 4     25.000  POINT (151.3783810000832 -33.37378272958927)
# 5     28.250  POINT (151.4414432201286 -33.35560261966515)
# 6     29.375  POINT (151.4377386698038 -33.35260847979748)
# 7     28.250  POINT (151.4408713304476 -33.34966122968194)
# 8     29.625    POINT (151.52071500959 -33.14175671000413)
# 9     38.500  POINT (151.4877225898257 -33.27922990003981)
# 10    32.750  POINT (151.5753480603647 -33.19457764034576)
# 11    34.750  POINT (151.4840762202415 -33.25284089988759)
# 12    34.750  POINT (151.4849214004024 -33.25426394032854)
# 13    32.125  POINT (151.5435231998358 -33.23507784966301)
# 14    34.750   POINT (151.4835088703381 -33.2515396501347)
# 15    28.250  POINT (151.4434480302025 -33.35225592037438)
# 16    28.125   POINT (151.387526000025 -32.68108085979378)
# 17    28.875  POINT (151.4892643200924 -32.80982144930039)
# 18    28.875   POINT (151.4892608001459 -32.8098386803108)
# 19    28.875   POINT (151.4334832496523 -32.8119258296133)
# 20    27.250  POINT (151.3603609595907 -32.84611059033142)
# 21    33.125  POINT (151.4446770500059 -33.29170594027687)
# 22    32.250  POINT (151.4737694895704 -33.36557426024387)
# 23    33.000  POINT (151.5057241798271 -33.23242732995726)
# 24    36.125  POINT (151.5156374202309 -33.25906182973961)
# 25    36.125   POINT (151.515866929915 -33.25836169043964)
# 26    34.375  POINT (151.5813507499372 -33.20232336982764)
# 27    25.375   POINT (151.3790970996515 -33.3641819397447)
# 28    34.375  POINT (151.5808197704162 -33.19827781996537)
# 29    28.250  POINT (151.4407541298992 -33.34849011992304)
# ...      ...                                           ...
# 2042  29.875  POINT (151.5562766296628 -32.72636893018193)
# 2043  29.625  POINT (151.5630301398292 -32.72739220038972)
# 2044  29.875   POINT (151.558461119785 -32.72680295019597)
# 2045  29.875  POINT (151.5582832302869 -32.72665534986447)
# 2046  29.875  POINT (151.5584707596179 -32.72625211993932)
# 2047  29.875  POINT (151.5543838301497 -32.72332334010002)
# 2048  29.750  POINT (151.5742723803661 -32.72731255013406)
# 2049  29.625  POINT (151.5734003203686 -32.72680614009124)
# 2050  29.375  POINT (151.5623165808456 -32.69748826027495)
# 2051  29.500   POINT (151.5768337700625 -32.7227879503036)
# 2052  29.500  POINT (151.5788257800857 -32.72070739033376)
# 2053  29.750  POINT (151.5784738798658 -32.72784292980731)
# 2054  29.375  POINT (151.5695175702797 -32.70835321992513)
# 2055  29.500  POINT (151.5819470697015 -32.71647096026658)
# 2056  29.375  POINT (151.5694527804216 -32.70887845997288)
# 2057  29.375  POINT (151.5695953697306 -32.70907421989926)
# 2058  29.375  POINT (151.5708942803468 -32.69945995011653)
# 2059  29.375  POINT (151.5717471110404 -32.69960956313076)
# 2060  29.375  POINT (151.5707127342054 -32.70709340283821)
# 2061  29.375  POINT (151.5711478100235 -32.70753993961648)
# 2062  29.500   POINT (151.5798280601169 -32.7011411400515)
# 2063  29.750  POINT (151.5905850201826 -32.70225136121132)
# 2064  29.500   POINT (151.580462619954 -32.69678363965318)
# 2065  29.750  POINT (151.5900221003398 -32.70281009021346)
# 2066  29.500   POINT (151.580628130284 -32.69693332011661)
# 2067  29.500   POINT (151.580721249686 -32.69620719040944)
# 2068  29.750  POINT (151.5984185558717 -32.70322437100788)
# 2069  29.750  POINT (151.5928329898506 -32.69724263384046)
# 2070  29.125   POINT (151.579092330147 -32.69554659969577)
# 2071  29.375   POINT (151.5733681696054 -32.6997212796133)
#
# [2072 rows x 141 columns]

# %% [markdown]
# ### List of column headings

# %%
df.columns
# Out:
# Index(['OBJECTID_1', 'OBJECTID_2', 'OBJECTID', 'createdate', 'srcid',
#        'assessoff', 'title', 'teamid', 'dateinsp', 'agency',
#        ...
#        'N1RR', 'P1RR', 'P6RR', 'PIRR', 'PTEA', 'NSWG', 'PGWS', 'PSMW', 'PSWG',
#        'geometry'],
#       dtype='object', length=141)

# %% [markdown]
# # Just do some quick cleaning up of the data

# %% [markdown]
# There are a number of blank fields throughout the data where a value was not entered into the dataset by the assessor. We need to keep track of the missing data, as well as the entered data, so we will find all 'NaN' values in the dataset, and change these to 'Not given' so we can include them in subsequent analyses.

# %%
df = df.fillna('Not given')

# %% [markdown]
# ### How many entries do we have for each column?
# I.e. not NaN. Note that this does not check the contents of the field, only that something was written into it
#
# NB: Something isn't quite working here. Use the values listed in the text below, not the outputs from this cell

# %%
df.count()
# Out:
# OBJECTID_1    2072
# OBJECTID_2    2072
# OBJECTID      2072
# createdate    2072
# srcid         2072
# assessoff     2072
# title         2072
# teamid        2072
# dateinsp      2072
# agency        2072
# eventid       2072
# eventname     2072
# eventtype     2072
# areainspd     2072
# position_     2072
# number_       2072
# street        2072
# streettype    2072
# suburb        2072
# state_        2072
# postcode      2072
# country       2072
# longaddrss    2072
# gurasaddrs    2072
# latitude      2072
# longitude     2072
# workbnddes    2072
# owner         2072
# contactnum    2072
# permenter     2072
#               ...
# liftmove      2072
# ropeheight    2072
# medical       2072
# usarminfo     2072
# localsafet    2072
# tarping       2072
# tarpsize      2072
# roofrepair    2072
# chainsaw      2072
# crane         2072
# elevwkplat    2072
# othmachine    2072
# othmachdes    2072
# equipment     2072
# equipdesc     2072
# waterinund    2072
# maxwatrlev    2072
# validaddre    2072
# EICU_Degda    2072
# EICU_Deg_1    2072
# N1RR          2072
# P1RR          2072
# P6RR          2072
# PIRR          2072
# PTEA          2072
# NSWG          2072
# PGWS          2072
# PSMW          2072
# PSWG          2072
# geometry      2072
# Length: 141, dtype: int64

# %% [markdown]
# # EICU data for the Hunter Region ECL event:
#
# * Number of data entries = 2072
# * Lat/lon = 2062 (99.5%)
# * EICU_Degdamage - damage state rank = 2055 (99.2%)
# * Insurance state = 1821 (88%)
# * Building use = 1909 (92%)
# * Foundations / Structure / Roof type = 1821 (88%)
# * Water inundation = 1317 (64%)
# * Water level = 203 (10%)

# %% [markdown]
# # Lets explore some key fields in more detail...

# %%
damage = df.groupby('EICU_Degda').count()
damage.OBJECTID
# Out:
# EICU_Degda
# Destroyed - 76-100%         14
# Major Impact - 26-50%      147
# Minor Impact - 1-25%       376
# No Damage - 0%            1465
# Not given                   17
# Severe Impact - 51-75%      53
# Name: OBJECTID, dtype: int64

# %% [markdown]
# ## Damage and water?

# %%
order = ['No Damage - 0%', 'Minor Impact - 1-25%', 'Major Impact - 26-50%', 'Severe Impact - 51-75%', 'Destroyed - 76-100%']
ax = sns.countplot(x="EICU_Degda", hue="waterinund", data=df, order=order)
ax.legend(title="Water Damage?", loc=1)
ax.set_yscale("log", nonposy='clip')
plt.xticks(rotation=10)
plt.title('Damage State and presence of water')
plt.xlabel('Damage state')
# Out:
# Text(0.5, 0, 'Damage state')

# %% [markdown]
# There does seem to be some relationship between the presence of water and damage state. Note that the last two columns represent missing vales, and where the surveyor has selected 'not applicable'.

# %% [markdown]
# ## Damage by roof type

# %%
temp = []
for name, group in df.groupby('EICU_Degda'):
    numingroup = group['OBJECTID'].count()
    numroofs = group.groupby('roof').count()
    percroofs = numroofs['OBJECTID']/numingroup*100
    for keys in percroofs.keys():
        temp.append((name, keys, percroofs[keys]))

roofdamage = pd.DataFrame(temp, columns = ['Damage_state', 'Roof_type', 'Percent'])
roofdamage
# Out:
#               Damage_state       Roof_type     Percent
# 0      Destroyed - 76-100%  Metal Sheeting   42.857143
# 1      Destroyed - 76-100%  Not Applicable    7.142857
# 2      Destroyed - 76-100%       Not given   21.428571
# 3      Destroyed - 76-100%            Tile   28.571429
# 4    Major Impact - 26-50%  Fibre Sheeting    0.680272
# 5    Major Impact - 26-50%  Metal Sheeting   38.095238
# 6    Major Impact - 26-50%  Not Applicable    2.721088
# 7    Major Impact - 26-50%       Not given   27.891156
# 8    Major Impact - 26-50%            Tile   30.612245
# 9     Minor Impact - 1-25%  Fibre Sheeting    0.797872
# 10    Minor Impact - 1-25%  Metal Sheeting   25.797872
# 11    Minor Impact - 1-25%  Not Applicable    1.861702
# 12    Minor Impact - 1-25%       Not given   34.574468
# 13    Minor Impact - 1-25%            Tile   36.968085
# 14          No Damage - 0%  Fibre Sheeting    0.068259
# 15          No Damage - 0%  Metal Sheeting   25.460751
# 16          No Damage - 0%  Not Applicable    1.569966
# 17          No Damage - 0%       Not given    2.389078
# 18          No Damage - 0%           Other    0.204778
# 19          No Damage - 0%           Slate    0.204778
# 20          No Damage - 0%            Tile   70.102389
# 21               Not given       Not given  100.000000
# 22  Severe Impact - 51-75%  Fibre Sheeting    1.886792
# 23  Severe Impact - 51-75%  Metal Sheeting   24.528302
# 24  Severe Impact - 51-75%       Not given   47.169811
# 25  Severe Impact - 51-75%            Tile   26.415094

# %%
order = ['No Damage - 0%', 'Minor Impact - 1-25%', 'Major Impact - 26-50%', 'Severe Impact - 51-75%', 'Destroyed - 76-100%']
ax = sns.factorplot(x="Damage_state", y = 'Percent', hue="Roof_type", data=roofdamage, order=order, kind = 'bar', size = 10)
plt.xticks(rotation=10)
plt.title('Damage state and roof type')
plt.ylabel('Percent of damage category')
plt.xlabel('Damage state')
# Out:
# C:\WorkSpace\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\WorkSpace\anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 29.065625000000026, 'Damage state')

# %% [markdown]
# ## Damage by wall structure type

# %%
temp = []
for name, group in df.groupby('EICU_Degda'):
    numingroup = group['OBJECTID'].count()
    numroofs = group.groupby('structure_').count()
    percroofs = numroofs['OBJECTID']/numingroup*100
    for keys in percroofs.keys():
        temp.append((name, keys, percroofs[keys]))

structuredamage = pd.DataFrame(temp, columns = ['Damage_state', 'Structure_type', 'Percent'])
structuredamage
# Out:
#               Damage_state        Structure_type     Percent
# 0      Destroyed - 76-100%          Brick Veneer   35.714286
# 1      Destroyed - 76-100%        Not applicable   14.285714
# 2      Destroyed - 76-100%             Not given   21.428571
# 3      Destroyed - 76-100%           Steel Frame    7.142857
# 4      Destroyed - 76-100%          Timber Frame   21.428571
# 5    Major Impact - 26-50%          Brick Veneer   27.210884
# 6    Major Impact - 26-50%        Not applicable    2.040816
# 7    Major Impact - 26-50%             Not given   27.891156
# 8    Major Impact - 26-50%                 Other    3.401361
# 9    Major Impact - 26-50%           Steel Frame    0.680272
# 10   Major Impact - 26-50%          Timber Frame   35.374150
# 11   Major Impact - 26-50%  Unreinforced Masonry    3.401361
# 12    Minor Impact - 1-25%          Brick Veneer   35.106383
# 13    Minor Impact - 1-25%        Not applicable    1.595745
# 14    Minor Impact - 1-25%             Not given   34.574468
# 15    Minor Impact - 1-25%                 Other    1.595745
# 16    Minor Impact - 1-25%    Reinforced Masonry    0.797872
# 17    Minor Impact - 1-25%           Steel Frame    1.595745
# 18    Minor Impact - 1-25%          Timber Frame   22.872340
# 19    Minor Impact - 1-25%  Unreinforced Masonry    1.861702
# 20          No Damage - 0%          Brick Veneer   69.146758
# 21          No Damage - 0%        Not applicable    1.501706
# 22          No Damage - 0%             Not given    2.389078
# 23          No Damage - 0%                 Other    0.887372
# 24          No Damage - 0%    Reinforced Masonry    0.136519
# 25          No Damage - 0%           Steel Frame    0.204778
# 26          No Damage - 0%    Tilt Slab Concrete    0.068259
# 27          No Damage - 0%          Timber Frame   23.959044
# 28          No Damage - 0%  Unreinforced Masonry    1.706485
# 29               Not given             Not given  100.000000
# 30  Severe Impact - 51-75%          Brick Veneer   30.188679
# 31  Severe Impact - 51-75%             Not given   47.169811
# 32  Severe Impact - 51-75%    Reinforced Masonry    1.886792
# 33  Severe Impact - 51-75%          Timber Frame   18.867925
# 34  Severe Impact - 51-75%  Unreinforced Masonry    1.886792

# %%
order = ['No Damage - 0%', 'Minor Impact - 1-25%', 'Major Impact - 26-50%', 'Severe Impact - 51-75%', 'Destroyed - 76-100%']
ax = sns.factorplot(x="Damage_state", y = 'Percent', hue="Structure_type", data=structuredamage, order=order, 
                    kind = 'bar', size = 10)
plt.xticks(rotation=10)
plt.title('Damage state and structure type')
plt.ylabel('Percent of damage category')
plt.xlabel('Damage state')
# Out:
# C:\WorkSpace\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\WorkSpace\anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 29.065625000000026, 'Damage state')

# %% [markdown]
# # Can we find wind damage specifically?

# %%
order = ['No Damage - 0%', 'Minor Impact - 1-25%', 'Major Impact - 26-50%', 'Severe Impact - 51-75%', 'Destroyed - 76-100%']
ax = sns.countplot(x="EICU_Degda", hue="eventtype", data=df, order=order)
ax.legend(title="Damage event", loc=1)
ax.set_yscale("log", nonposy='clip')
plt.xticks(rotation=10)
plt.title('Damage States for flood vs storm')
plt.xlabel('Damage state')
# Out:
# Text(0.5, 0, 'Damage state')

# %% [markdown]
# # <font color=red>Question for follow up with NSWFR</font>
#
# It may be possible to distinguish between flood and storm damage, however it is not clear whether 'flood' damage refers specifically to riverine flooding, or whether water damage from a leaking roof is also classified as flood.

# %%
order = ['Stable', 'Minor', 'Moderate', 'Severe']
ax = sns.countplot(x="roofdam", hue="waterinund", data=df, order = order)
ax.legend(title="Water Damage?")
ax.set_yscale("log", nonposy='clip')
plt.xticks(rotation=10)
plt.title('Roof damage State and presence of water')
plt.xlabel('Roof damage state')
# Out:
# Text(0.5, 0, 'Roof damage state')

# %%
order = ['Stable', 'Minor', 'Moderate', 'Severe']
ax = sns.countplot(x="roofdam", hue="eventtype", data=df, order = order)
ax.legend(title="Event type")
ax.set_yscale("log", nonposy='clip')
plt.xticks(rotation=10)
plt.title('Roof damage State and presence of water')
plt.xlabel('Roof damage state')
# Out:
# Text(0.5, 0, 'Roof damage state')

# %% [markdown]
# No building with roof damage state listed attributes the damage to storm. This suggests that 'flood' is being used to describe any type of water damage, whether it is rising water, or water coming into the house another way.
#
# This is problematic, as it means it isn't possible to use the 'event type' tag to distinguish between these two scenarios.

# %% [markdown]
# ## NB
# Wind damage doesn't seem to be discernable from this dataset. Roof damage could be used a pseudo-proxy for storm damage, however it is not specifically marked as storm damage in the database. For all of the entries that have roof damage assessed, all of them list the event type as 'flood', not 'storm'. This suggests that water ingress from damaged roofs is classed as flood damage, not storm damage for this event.

# %% [markdown]
# # Can we generate a vulnerability-like curve of damage state and modelled wind?

# %% [markdown]
# Wind speed was output at each model time step in the ECL event ensemble simulations. These plots use the maximum wind speed over the all time steps for each grid point.
#
# In the first instance, two individual ensemble members (randomly chosen) were interrogated. It was found that these did not differ greatly, and so additional members were not further investigated.

# %% [markdown]
# ## The model outputs sustained wind speed. We would like to convert this to wind gust.
#
# To do this, we applied a gust conversion factor of 1.6 to see if this improved the results.

# %%
#df['combined_alltimes_maxwind_stage4_ens12'] = df['combined_alltimes_maxwind_stage4_ens12'] * 1.6
#df['combined_alltimes_maxwind_stage4_ens22'] = df['combined_alltimes_maxwind_stage4_ens22'] * 1.6

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degda", x = "PSWG", data = df, order = order)
sns.swarmplot(y = "EICU_Degda", x = "PSWG", data = df, order = order, color = "0.2")
plt.xlabel("Surface gust wind speed (m/s)")
plt.ylabel("Damage state")
# Out:
# Text(0, 0.5, 'Damage state')

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degda", x = "PSWG", data = df, order = order)
sns.swarmplot(y = "EICU_Degda", x = "PSWG", data = df, order = order, color = "0.2")
plt.xlabel("Surface gust wind speed (m/s)")
plt.ylabel("Damage state")
# Out:
# Text(0, 0.5, 'Damage state')

# %% [markdown]
# When the gust factor is applied, there emerges a threshold-like response to wind speed at around 12 m/s (43 km/hr). The damage relationship however, doesn't increase with increasing wind. The greatest wind speeds are not experienced by the buildings that sustained the greatest damage.
#
# This suggests that wind may not be the driving factor in generating damage in this event.

# %% [markdown]
# # How about rain?
#
# Is it possible that rain is the factor driving the damage in this event?
#
# The rain rate (kg m-2 s-1) was output for each model time step, and the maximum rain rate throughout the model run was extracted. Again, two random ensemble members were chosen for initial investigation.

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degda", x = "P6RR", data = df, order = order)
sns.swarmplot(y = "EICU_Degda", x = "P6RR", data = df, order = order, 
              color = "0.2")
plt.xlabel("Maximum 6-hour rainfall rate (mm/6hrs)")
plt.ylabel("Damage state")
# Out:
# Text(0, 0.5, 'Damage state')

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degda", x = "PTEA", data = df, order = order)
sns.swarmplot(y = "EICU_Degda", x = "PTEA", data = df, order = order, 
              color = "0.2")
plt.xlabel("Total accumulated precipitation (mm)")
plt.ylabel("Damage state")
# Out:
# Text(0, 0.5, 'Damage state')

# %% [markdown]
# The results from the two ensemble members are quite different, suggesting that this variable is much more spatially variable. To address this, we extracted the maximum rain rate for each ensemble member, then calculated the average of those rain rates for each grid box.

# %% [markdown]
# ## Ensemble mean rain rate over all time steps

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degdamage", x = "combined_alltimes_accum_ls_rainrate_stage4_ensMEAN", data = df, order = order)
sns.swarmplot(y = "EICU_Degdamage", x = "combined_alltimes_accum_ls_rainrate_stage4_ensMEAN", data = df, order = order, 
              color = "0.2")

# %% [markdown]
# ## Ensemble standard deviation of rain rate over all ensemble members

# %%
order = ['Destroyed - 76-100%', 'Severe Impact - 51-75%', 'Major Impact - 26-50%', 'Minor Impact - 1-25%', 'No Damage - 0%']
sns.boxplot(y = "EICU_Degdamage", x = "combined_alltimes_accum_ls_rainrate_stage4_ensSTD", data = df, order = order)
sns.swarmplot(y = "EICU_Degdamage", x = "combined_alltimes_accum_ls_rainrate_stage4_ensSTD", data = df, order = order, 
              color = "0.2")

# %% [markdown]
# # Results
#
# #### The relationship between damage and rain rate looks much more convincing than with wind. This suggests that it was the rainfall that was the driver of damamge in this event.
#
# #### This makes sense, as the design wind speed for houses is 38-40 m/s, which is the upper limit of modelled wind speeds for building locations. It is therefore not likely that the wind speed was sufficiently high enough to break apart houses.
#
# #### The much more logical solution is that the rain rate caused water ingress to houses, either directly through weaknesses in the structure, or through damage to the building's exterior caused by trees falling.

# %% [markdown]
# # Can we find any relationship between tree damage and wind speed?

# %% [markdown]
# ## Locations where 'dangertree' column has been ticked

# %%
tree_text = df[df['dangertree'].str.contains('Yes')]
tree_text.shape
# Out:
# (14, 141)

# %%
sns.distplot(tree_text.combined_alltimes_maxwind_stage4_ens12)
plt.title('Histogram of wind speeds for entries with the \'dangertree\' column ticked')
plt.xlabel('Wind speed (gust factor = 1.6, m/s)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-8b62af743511> in <module>
# ----> 1 sns.distplot(tree_text.combined_alltimes_maxwind_stage4_ens12)
#       2 plt.title('Histogram of wind speeds for entries with the \'dangertree\' column ticked')
#       3 plt.xlabel('Wind speed (gust factor = 1.6, m/s)')
#
# C:\WorkSpace\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'combined_alltimes_maxwind_stage4_ens12'

# %% [markdown]
# ## Look for terms relating to tree in the comments field

# %%
tree_text = df[df['Comments'].str.contains('tree|branch', case = False)]
tree_text.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\WorkSpace\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comments'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-c10840938cc6> in <module>
# ----> 1 tree_text = df[df['Comments'].str.contains('tree|branch', case = False)]
#       2 tree_text.shape
#
# C:\WorkSpace\anaconda3\lib\site-packages\geopandas\geodataframe.py in __getitem__(self, key)
#     453         GeoDataFrame.
#     454         """
# --> 455         result = super(GeoDataFrame, self).__getitem__(key)
#     456         geo_col = self._geometry_column_name
#     457         if isinstance(key, string_types) and key == geo_col:
#
# C:\WorkSpace\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\WorkSpace\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comments'

# %%
sns.distplot(tree_text.combined_alltimes_maxwind_stage4_ens12)
plt.title('Histogram of wind speeds for entries with \'tree\' or \'branch\' mentioned in the comments')
plt.xlabel('Wind speed (gust factor = 1.6, m/s)')
